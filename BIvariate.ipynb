# %%
import pandas as pd;
import numpy as np;
import matplotlib as mat;

# %%
preprocessedPlacement = pd.read_csv("PreProcessed_Placement.csv")

preprocessedPlacement
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#preprocessedPlacement.quary({"etest_p"})

preprocessedPlacement.loc[(preprocessedPlacement["salary"] > 500000)]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 119    120      M   60.8  Central  68.40  Central  Commerce      64.6
# 150    151      M   71.0  Central  58.66  Central   Science      58.0
# 177    178      F   73.0  Central  91.15   Others  Commerce      79.0
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 119  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  706250.0
# 150   Sci&Tech    Yes    56.00        Mkt&Fin  61.30  Placed  690000.0
# 177  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0

# %%
#preprocessedPlacement.loc[(preprocessedPlacement["specialisation"] < 200000)]

# %%
preprocessedPlacement["salary"].mean()
# Out:
# 197615.11627906977

# %%
preprocessedPlacement["salary"].std()
# Out:
# 150305.84416934152

# %%
dir(preprocessedPlacement)

# %%
preprocessedPlacement.cov()
# Out:
#                  sl_no          ssc_p          hsc_p       degree_p  \
# sl_no      3870.000000     -52.641355     -59.598879     -41.465047
# ssc_p       -52.641355     117.228377      58.853253      42.702550
# hsc_p       -59.598879      58.853253     112.063731      33.684453
# degree_p    -41.465047      42.702550      33.684453      53.604710
# etest_p      52.556168      37.659225      33.838355      22.078774
# mba_p         8.102336      24.535952      21.517688      17.185200
# salary    11383.177570  908858.485818  731007.850848  466336.264888
#
#                 etest_p          mba_p        salary
# sl_no         52.556168       8.102336  1.138318e+04
# ssc_p         37.659225      24.535952  9.088585e+05
# hsc_p         33.838355      21.517688  7.310079e+05
# degree_p      22.078774      17.185200  4.663363e+05
# etest_p      176.251018      16.886973  3.727004e+05
# mba_p         16.886973      34.028376  1.239934e+05
# ...

# %%
preprocessedPlacement["ssc_p"].cov(preprocessedPlacement["hsc_p"])
# Out:
# 58.853252975440135

# %%
preprocessedPlacement.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.090500 -0.091039  0.063636  0.022327  0.001217
# ssc_p    -0.078155  1.000000  0.513478  0.538686  0.261993  0.388478  0.558475
# hsc_p    -0.090500  0.513478  1.000000  0.434606  0.240775  0.348452  0.459424
# degree_p -0.091039  0.538686  0.434606  1.000000  0.227147  0.402376  0.423762
# etest_p   0.063636  0.261993  0.240775  0.227147  1.000000  0.218055  0.186775
# mba_p     0.022327  0.388478  0.348452  0.402376  0.218055  1.000000  0.141417
# salary    0.001217  0.558475  0.459424  0.423762  0.186775  0.141417  1.000000

# %%
preprocessedPlacement["ssc_p"].corr(preprocessedPlacement["hsc_p"])
# Out:
# 0.5134776662265998

# %%
preprocessedPlacement.corrwith(preprocessedPlacement["salary"])
# Out:
# sl_no       0.001217
# ssc_p       0.558475
# hsc_p       0.459424
# degree_p    0.423762
# etest_p     0.186775
# mba_p       0.141417
# salary      1.000000
# dtype: float64

# %%
preprocessedPlacement["mba_p"].corr(preprocessedPlacement["salary"])
# Out:
# 0.14141713944325943

# %% [markdown]
# ## T-Test

# %% [markdown]
# ## Independent Sample
# ## Different group(male, female) but same condition(salary)
#
# ## (is significantly same the salary of male and female candidate?)

# %%
from scipy.stats import ttest_ind

preprocessedPlacement = preprocessedPlacement.dropna()

male = preprocessedPlacement[preprocessedPlacement["gender"] == "M"]["salary"]

female = preprocessedPlacement[preprocessedPlacement["gender"] == "F"]["salary"]

ttest_ind(male, female)
# Out:
# Ttest_indResult(statistic=2.0937842507001165, pvalue=0.03746230397067219)

# %% [markdown]
# ## Hypothesis testing

# %%
test_ans= ttest_ind(male, female)

test_ans.pvalue
# Out:
# 0.03746230397067219

# %%
print("Null Hypothesis : There is no significantly same the salary of male and female candidate")
    
print("Alternative Hypothesis : There is significantly same the salary of male and female candidate")

messageList = []

Hypo_pvalue = test_ans.pvalue

if(Hypo_pvalue < 0.05):
    
    print("Reject Null Hypothesis")
    print("Accept Alternate Hypothesis")
    
    messageTrueHypothesis = "Accept Alternate Hypothesis"
            
else:
    
    print("Reject Alternate Hypothesis")
    
    print("Accept Null Hypothesis")

    messageTrueHypothesis = "Accept Null Hypothesis"

messageList.append(messageTrueHypothesis)
# Out:
# Null Hypothesis : There is no significantly same the salary of male and female candidate
# Alternative Hypothesis : There is significantly same the salary of male and female candidate
# Reject Null Hypothesis
# Accept Alternate Hypothesis

# %%
messageList
# Out:
# ['Accept Alternate Hypothesis']

# %% [markdown]
# ## Dependent Sample
# ## Same group(male) but different condition(ssc_p, hsc_p)

# %%
from scipy.stats import ttest_rel

male = preprocessedPlacement[preprocessedPlacement["gender"] == "M"]["ssc_p"]

male_1 = preprocessedPlacement[preprocessedPlacement["gender"] == "M"]["hsc_p"]

ttest_rel(male, male_1)
# Out:
# Ttest_relResult(statistic=0.6842940392688153, pvalue=0.4949370716000775)

# %%
t_ans = ttest_rel(male, male_1)

t_ans.pvalue
# Out:
# 0.4949370716000775

# %%
print("Null Hypothesis : There is no significantly same ssc_p and hsc_p of male candidate")
    
print("Alternative Hypothesis : There is significantly same ssc_p and hsc_p of male candidate")

messageHypothesis = []

testT = t_ans.pvalue

if(testT < 0.05):
    
    print("Reject Null Hypothesis")

    print("Accpet alternative Hypothesis")
    
    messageBox = "Accpet alternative Hypothesis"
    
else:
    
    print("Reject Alternative Hypothesis")
    
    print("Accept Null Hypothesis")
    
    messageBox = "Accept Null Hypothesis"
    
messageHypothesis.append(messageBox)
# Out:
# Null Hypothesis : There is no significantly same ssc_p and hsc_p of male candidate
# Alternative Hypothesis : There is significantly same ssc_p and hsc_p of male candidate
# Reject Alternative Hypothesis
# Accept Null Hypothesis

# %%
messageHypothesis
# Out:
# ['Accept Null Hypothesis']

# %%
preprocessedPlacement
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# ## Anova - Analysis of Variance
#
# ## one way classification

# %%
import scipy.stats as stats

stats.f_oneway(preprocessedPlacement["ssc_p"], preprocessedPlacement["hsc_p"], preprocessedPlacement["degree_p"])
# Out:
# F_onewayResult(statistic=0.695991304348204, pvalue=0.49895574725815317)

# %%
stats.f_oneway(preprocessedPlacement["etest_p"], preprocessedPlacement["mba_p"])
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %%
variancePValue = stats.f_oneway(preprocessedPlacement["etest_p"], preprocessedPlacement["mba_p"])

# %%
valueSet = variancePValue.pvalue

valueSet
# Out:
# 4.672547689133573e-21

# %%
print("Null Hypothesis : There is no significantly variance of etest_p and mba_p")

print("Alternative Hypothesis : There is significantly variance of between etest_p and mba_p")

messageList = []

valueSet = variancePValue.pvalue

if(valueSet < 0.05):
    
    print("Reject Null Hypothesis")
    print("Accept Alternative Hypothesis")
    messageNote = "Accept Alternative Hypothesis"
else:
    print("Reject Alternative Hypothesis")
    print("Accept Null Hypothesis")
    messageNote = "Accept Null Hypothesis"

messageList.append(messageNote)
# Out:
# Null Hypothesis : There is no significantly variance of etest_p and mba_p
# Alternative Hypothesis : There is significantly variance of between etest_p and mba_p
# Reject Null Hypothesis
# Accept Alternative Hypothesis

# %%
messageList
# Out:
# ['Accept Alternative Hypothesis']

# %% [markdown]
# ## Two way classification

# %%
convertProcedure = preprocessedPlacement.iloc[0:215]

convertProcedure
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
convertDataset = pd.get_dummies(convertProcedure, drop_first = True)

convertDataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary  gender_M  \
# 0        1  67.00  91.00     58.00     55.0  58.80  270000.0         1
# 1        2  79.33  78.33     77.48     86.5  66.28  200000.0         1
# 2        3  65.00  68.00     64.00     75.0  57.80  250000.0         1
# 3        4  56.00  52.00     52.00     66.0  59.43       0.0         1
# 4        5  85.80  73.60     73.30     96.8  55.50  425000.0         1
# ..     ...    ...    ...       ...      ...    ...       ...       ...
# 210    211  80.60  82.00     77.60     91.0  74.49  400000.0         1
# 211    212  58.00  60.00     72.00     74.0  53.62  275000.0         1
# 212    213  67.00  67.00     73.00     59.0  69.72  295000.0         1
# 213    214  74.00  66.00     58.00     70.0  60.23  204000.0         0
# 214    215  62.00  58.00     53.00     89.0  60.22       0.0         1
#
#      ssc_b_Others  hsc_b_Others  hsc_s_Commerce  hsc_s_Science  \
# ...

# %%
convertDataset.shape

# %%
convertDatasetVal = convertDataset.drop(columns=convertDataset.iloc[:, 6:17])

# %%
#convertDataset.drop(convertDataset.columns[[0, 6, 7, 8, 9]], axis = 1, inplace = True);

# %%
convertDatasetVal.drop(convertDataset.columns[[0]], axis = 1, inplace = True);

# %%
convertDatasetVal
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p
# 0    67.00  91.00     58.00     55.0  58.80
# 1    79.33  78.33     77.48     86.5  66.28
# 2    65.00  68.00     64.00     75.0  57.80
# 3    56.00  52.00     52.00     66.0  59.43
# 4    85.80  73.60     73.30     96.8  55.50
# ..     ...    ...       ...      ...    ...
# 210  80.60  82.00     77.60     91.0  74.49
# 211  58.00  60.00     72.00     74.0  53.62
# 212  67.00  67.00     73.00     59.0  69.72
# 213  74.00  66.00     58.00     70.0  60.23
# 214  62.00  58.00     53.00     89.0  60.22
#
# [215 rows x 5 columns]

# %%
convertDatasetVal.iloc[0].values
# Out:
# array([67. , 91. , 58. , 55. , 58.8])

# %%
#convertDataset.iloc[1].values

# %%
#students = convertDatasetVal.iloc[:].values

# %%
#students

# %%
#convertDatasetVal.iloc[200].values

# %%
obj = [[] for i in range(215)]

# %%
obj

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\envs\virtualml\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 215 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2716\973562007.py in <module>
# ----> 1 convertDatasetVal.loc[215].values
#
# ~\Anaconda3\envs\virtualml\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
# ...

# %%
rowValues_1 = convertDatasetVal.iloc[0].values

rowValues_2 = convertDatasetVal.iloc[1].values

rowValues_3 = convertDatasetVal.iloc[2].values

rowValues_4 = convertDatasetVal.iloc[3].values

rowValues_5 = convertDatasetVal.iloc[4].values

# %%
listA = []

listB = []

listC = []

listD = []

listE = []

for columnName in rowValues_1:
    
    listA.append(columnName)
    
for columnName_2 in rowValues_2:
    
    listB.append(columnName_2)
    
for columnName_3 in rowValues_3:
    
    listC.append(columnName_3)
    
for columnName_4 in rowValues_4:
    
    listD.append(columnName_4)
    
for columnName_5 in rowValues_5:
    
    listE.append(columnName_5)

# %%
listA

# %%
convertDatasetVal = pd.DataFrame({"student_1" : listA, "student_2" : listB, "student_3": listC, "student_4" : listD, "student_5" : listE})

# %%
convertDatasetVal
# Out:
#    student_1  student_2  student_3  student_4  student_5
# 0       67.0      79.33       65.0      56.00       85.8
# 1       91.0      78.33       68.0      52.00       73.6
# 2       58.0      77.48       64.0      52.00       73.3
# 3       55.0      86.50       75.0      66.00       96.8
# 4       58.8      66.28       57.8      59.43       55.5

# %%
#convertProcedure

# %%
import scipy.stats as stats

stats.f_oneway(convertDatasetVal["student_1"], convertDatasetVal["student_2"])
# Out:
# F_onewayResult(statistic=2.516800622342821, pvalue=0.1513000405740113)

# %% [markdown]
# ## Hypothesis test for Student 1 and Student 2

# %%
HypoTest = stats.f_oneway(convertDatasetVal["student_1"], convertDatasetVal["student_2"])

HypoTest.pvalue
# Out:
# 0.1513000405740113

# %%
print("Null Hypothesis : There is no significantly same of student 1 and student 2")

print("Alternative Hypothesis : There is significantly same of student 1 and student 2")

messageList = []

valueSet = HypoTest.pvalue

if(valueSet < 0.05):
    
    print("Reject Null Hypothesis")
    print("Accept Alternative Hypothesis")
    messageNote = "Accept Alternative Hypothesis"
else:
    print("Reject Alternative Hypothesis")
    print("Accept Null Hypothesis")
    messageNote = "Accept Null Hypothesis"

messageList.append(messageNote)
# Out:
# Null Hypothesis : There is no significantly same of student 1 and student 2
# Alternative Hypothesis : There is significantly same of student 1 and student 2
# Reject Alternative Hypothesis
# Accept Null Hypothesis

# %%
messageList
# Out:
# ['Accept Null Hypothesis']
